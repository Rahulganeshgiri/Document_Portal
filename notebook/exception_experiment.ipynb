# %%
import sys
import traceback

# %%
from logger import custom_logger
logger = custom_logger.CustomLogger().get_logger("exception_experiment")

# %%
class DocumentPortalException(Exception):
    """Custom exception class for Document Portal application."""
    def __init__(self,error_message,error_details:sys):
        _,_,exc_tb = error_details.exc_info()
        exc_tb.tb_frame.f_code.co_filename
        self.file_name = exc_tb.tb_frame.f_code.co_filename
        self.line_number = exc_tb.tb_lineno
        self.error_message = str(error_message)
        self.traceback_str = ''.join(traceback.format_exception(*error_details.exc_info()))


    def __str__(self):
        return f"""Error occurred in script: {self.file_name} at line number: {self.line_number} 
        error message: {self.error_message} 
        Traceback Details: {self.traceback_str}"""

if __name__=="__main__":
    try:
        a=1/0
        print(a)
    except Exception as e:
        app_exc = DocumentPortalException(e,sys)
        logger.error(app_exc)
        raise app_exc
# Out:
# {"timestamp": "2025-11-13T18:22:25.006328Z", "level": "error", "event": "DocumentPortalException(ZeroDivisionError('division by zero'), <module 'sys' (built-in)>)"}
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 19
#      18 try:
# ---> 19     a=1/0
#      20     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[11], line 24
#      22 app_exc = DocumentPortalException(e,sys)
#      23 logger.error(app_exc)
# ---> 24 raise app_exc
#
# DocumentPortalException: Error occurred in script: C:\Users\Rahul\AppData\Local\Temp\ipykernel_38640\1950536334.py at line number: 19
#         error message: division by zero
#         Traceback Details: Traceback (most recent call last):
# ...
